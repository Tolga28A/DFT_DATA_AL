# %%
import numpy as np
import seaborn as sns

en_ave = np.loadtxt('energy_ave.dat')
en_rms = np.loadtxt('energy_rms.dat')

fig, (ax1, ax2) = plt.subplots(1,2,sharex=True, sharey=True,figsize=(12,5))

sns.heatmap(en_ave, ax=ax1).set_title('Average absolute per-atom energy error')
ax1.set_ylabel("f")
ax1.set_xlabel("s")

sns.heatmap(en_rms, ax=ax2).set_title('Root-mean-squared per-atom energy error')
ax1.set_ylabel("f")
ax1.set_xlabel("s")

fig.tight_layout() 
plt.show()
